# %%
import pandas as pd #pandas
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('insurance_claims_raw.xlsx')
df.head()
# Out:
#    months_as_customer   age  policy_number policy_bind_date policy_state  \
# 0                 328  48.0         521585       2014-10-17           OH
# 1                 228  42.0         342868       2006-06-27           IN
# 2                 134  29.0         687698       2000-09-06           OH
# 3                 256  41.0         227811       1990-05-25           IL
# 4                 228  44.0         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500             1000.0                1406.91               0
# 1    250/500             2000.0                1197.22         5000000
# 2    100/300             2000.0                1413.14         5000000
# 3    250/500             2000.0                1415.74         6000000
# 4   500/1000             1000.0                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %% [markdown]
# # Data Checking

# %%
df.describe()
# Out:
#        months_as_customer         age  policy_number  \
# count         1000.000000  998.000000    1000.000000
# mean           203.954000   38.962926  546238.648000
# min              0.000000   19.000000  100804.000000
# 25%            115.750000   32.000000  335980.250000
# 50%            199.500000   38.000000  533135.000000
# 75%            276.250000   44.000000  759099.750000
# max            479.000000   64.000000  999435.000000
# std            115.113174    9.135425  257063.005276
#
#                     policy_bind_date  policy_deductable  \
# count                           1000         998.000000
# mean   2002-02-08 04:40:47.999999872        1134.268537
# min              1990-01-08 00:00:00         500.000000
# 25%              1995-09-19 00:00:00         500.000000
# 50%              2002-04-01 12:00:00        1000.000000
# 75%              2008-04-21 12:00:00        2000.000000
# max              2015-02-22 00:00:00        2000.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          998 non-null    float64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   datetime64[ns]
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            998 non-null    float64
#  7   policy_annual_premium        997 non-null    float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      999 non-null    object
# ...

# %% [markdown]
# # Data Engineering

# %%
def key_summary(df):
    #df = df.drop('_c39', axis=1)
    res = pd.DataFrame(df.isnull().sum())
    res.columns = ['no_nulls']
    res['population_mode'] = np.nan
    res['population_average'] = np.nan
    for x in res.index:
        if df[x].dtype == 'object':
            res['population_mode'][x] = df[x].mode()[0]
        if (df[x].dtype =='int64') or (df[x].dtype =='float64'):
            res['population_average'][x] = round(df[x].mean(),4)         
        
    return res
mean_mode_data=key_summary(df) #call function and create table of key statistics
mean_mode_data
# Out:
# C:\Users\monde\AppData\Local\Temp\ipykernel_25592\834728406.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   res['population_average'][x] = round(df[x].mean(),4)
# ...

# %%
df2 = df.copy()

# %%
#VERSION 2: populating missing data

#static information
mean_mode_data=key_summary(df) #call function and create table of key statistics

def fill_na(new_df):
    new_df = new_df.drop('_c39', axis=1)
        
    #Fill missing values with mode or mean.
    for x in new_df.columns:
        if new_df[x].dtype == 'object':
            new_df[x] = new_df[x].fillna(mean_mode_data['population_mode'].loc[x])
        if (new_df[x].dtype == 'int64') or (new_df[x].dtype == 'float64'):
            new_df[x] = new_df[x].fillna(mean_mode_data['population_average'].loc[x])
            
    #splitting out dates
    new_df['bind_year'] = new_df['policy_bind_date'].dt.year
    new_df['bind_month'] = new_df['policy_bind_date'].dt.month
    new_df['bind_day'] = new_df['policy_bind_date'].dt.day

    new_df['incident_year'] = new_df['incident_date'].dt.year
    new_df['incident_month'] = new_df['incident_date'].dt.month
    new_df['incident_day'] =new_df['incident_date'].dt.day


    new_df = new_df.drop(['policy_bind_date', 'incident_date'], axis=1)
    
    #reordering the columns
    new_df = new_df[[column for column in new_df.columns if column != 'fraud_reported'] + ['fraud_reported']]
    
    return new_df
    
#VERSION 1: populating missing data
'''
#VERSION 1: static information
avg_age = round(df['age'].mean(),0)
avg_policy_deductable = round(df['policy_deductable'].mean(),2)
avg_policy_annual_premium = round(df['policy_annual_premium'].mean(),2)
mode_insured_education_level = df['insured_education_level'].mode()[0]
#insured_hobbies
#capital-gains

#data clean up
def fill_na(df):
    df['age'] = df['age'].fillna(avg_age) #fill blank age
    df['policy_deductable'] = df['policy_deductable'].fillna(avg_policy_deductable) #fill black policy deductable
    df['policy_annual_premium'] = df['policy_annual_premium'].fillna(avg_policy_annual_premium) #fill black policy annual premium
    df['insured_education_level'] = df['insured_education_level'].fillna(mode_insured_education_level) #fill black insured education level
    
    return df.info()
    
'''
# Out:
# C:\Users\monde\AppData\Local\Temp\ipykernel_25592\834728406.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   res['population_average'][x] = round(df[x].mean(),4)
# ...

# %%
df2 = fill_na(df2)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   float64
#  2   policy_number                1000 non-null   int64
#  3   policy_state                 1000 non-null   object
#  4   policy_csl                   1000 non-null   object
#  5   policy_deductable            1000 non-null   float64
#  6   policy_annual_premium        1000 non-null   float64
#  7   umbrella_limit               1000 non-null   int64
#  8   insured_zip                  1000 non-null   int64
#  9   insured_sex                  1000 non-null   object
#  10  insured_education_level      1000 non-null   object
#  11  insured_occupation           1000 non-null   object
#  12  insured_hobbies              1000 non-null   object
# ...

# %%
df2.shape
# Out:
# (1000, 43)

# %% [markdown]
# # Building a classification model

# %%
df2['fraud_reported'].value_counts()
# Out:
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64

# %%
#import libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import resample

# %%
X = df2.iloc[:,:-1]
y = df2.iloc[:,-1]

# %%
X = pd.get_dummies(X)
X.shape
# Out:
# (1000, 1168)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=11, test_size=0.20)

# %% [markdown]
# # Random forest without resampling data

# %%
rf = RandomForestClassifier(random_state=11)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=11)

# %%
y_test_pred_rf = rf.predict(X_test)
print(pd.DataFrame(confusion_matrix(y_test, y_test_pred_rf), columns=['N', 'Y'], index=['N', 'Y']))
print(classification_report(y_test, y_test_pred_rf))
# Out:
#      N   Y
# N  141   8
# Y   41  10
#               precision    recall  f1-score   support
#
#            N       0.77      0.95      0.85       149
#            Y       0.56      0.20      0.29        51
#
#     accuracy                           0.76       200
#    macro avg       0.67      0.57      0.57       200
# weighted avg       0.72      0.76      0.71       200

# %% [markdown]
# # Combine training data for resampling

# %%
resamp_data = pd.concat([X_train, y_train],axis=1)

# %%
resamp_data.shape
# Out:
# (800, 1169)

# %%
fraud_Y = resamp_data[resamp_data['fraud_reported']=='Y']
fraud_N = resamp_data[resamp_data['fraud_reported']=='N']
print(fraud_Y.shape)
print(fraud_N.shape)
# Out:
# (196, 1169)
# (604, 1169)

# %%
fraud_Y_resize = resample(fraud_Y, random_state=11, n_samples=len(fraud_N), replace=True)

# %%
fraud_Y_resize.shape
# Out:
# (604, 1169)

# %%
df_resampled = pd.concat([fraud_N, fraud_Y_resize])
df_resampled.shape
# Out:
# (1208, 1169)

# %%
X_train_resampled = df_resampled.iloc[:,:-1]
y_train_resampled = df_resampled.iloc[:,-1]

# %%
df_resampled.head()
# Out:
#      months_as_customer   age  policy_number  policy_deductable  \
# 832                 295  46.0         863749              500.0
# 797                 136  33.0         804608             1000.0
# 49                  192  35.0         582011             1000.0
# 867                 212  39.0         167466             1000.0
# 514                 479  60.0         232854             2000.0
#
#      policy_annual_premium  umbrella_limit  insured_zip  capital-gains  \
# 832                1265.84               0       605743        52200.0
# 797                 855.14               0       458582        37900.0
# 49                 1245.89               0       435481            0.0
# 867                1255.35               0       454176        60300.0
# 514                1304.83               0       473638            0.0
#
#      capital-loss  incident_hour_of_the_day  ...  auto_model_RAM  \
# 832        -44500                        10  ...           False
# ...

# %% [markdown]
# # training a model - Random Forest

# %%
rf_model = RandomForestClassifier(random_state=11)

# %%
rf_model.fit(X_train_resampled, y_train_resampled)
# Out:
# RandomForestClassifier(random_state=11)

# %%
y_test_pred = rf_model.predict(X_test)

# %%
print(confusion_matrix(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# [[134  15]
#  [ 34  17]]
#               precision    recall  f1-score   support
#
#            N       0.80      0.90      0.85       149
#            Y       0.53      0.33      0.41        51
#
#     accuracy                           0.76       200
#    macro avg       0.66      0.62      0.63       200
# weighted avg       0.73      0.76      0.73       200

# %% [markdown]
# # train logistic regression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train_resampled, y_train_resampled)
# Out:
# C:\Users\monde\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_test_pred_lr = lr.predict(X_test)
print(confusion_matrix(y_test, y_test_pred_lr))
print(classification_report(y_test, y_test_pred_lr))
# Out:
# [[83 66]
#  [23 28]]
#               precision    recall  f1-score   support
#
#            N       0.78      0.56      0.65       149
#            Y       0.30      0.55      0.39        51
#
#     accuracy                           0.56       200
#    macro avg       0.54      0.55      0.52       200
# weighted avg       0.66      0.56      0.58       200
